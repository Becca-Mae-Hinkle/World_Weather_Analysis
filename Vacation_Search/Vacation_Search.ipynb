# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
# Dependencies and Setup
import pandas as pd
import numpy as np
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps API key
gmaps.configure(api_key=g_key)

# %%
# 1. Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("WeatherPy_Database.csv")
city_data_df.head()
# Out:
#    Unnamed: 0                       City Country      Lat       Lng  Max Temp  \
# 0           0  Santa Isabel Do Rio Negro      BR  -0.4139  -65.0192     80.89
# 1           1                   Acapulco      MX  16.8634  -99.8901     85.82
# 2           2                      Kenai      US  60.5544 -151.2583     28.45
# 3           3                  Jamestown      US  42.0970  -79.2353     41.09
# 4           4                 Nikolskoye      RU  59.7035   30.7861     22.87
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        79         100        1.30     overcast clouds
# 1        62           0        8.05           clear sky
# 2       100         100        4.61     overcast clouds
# 3        52         100       15.01     overcast clouds
# 4        94          98       10.56     overcast clouds

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria 
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 60
# What is the maximum temperature you would like for your trip? 95

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                  (city_data_df["Max Temp"] >= min_temp)]

preferred_cities_df.head(10)
# Out:
#     Unnamed: 0                       City Country      Lat       Lng  \
# 0            0  Santa Isabel Do Rio Negro      BR  -0.4139  -65.0192
# 1            1                   Acapulco      MX  16.8634  -99.8901
# 5            5                    Rikitea      PF -23.1203 -134.9692
# 6            6                   Celestun      MX  20.8667  -90.4000
# 7            7                  Esperance      AU -33.8667  121.9000
# 11          11                   Coquimbo      CL -29.9533  -71.3436
# 14          14                       Chuy      UY -33.6971  -53.4616
# 19          19                East London      ZA -33.0153   27.9116
# 23          23                 Porto Novo      BJ   6.4965    2.6036
# 24          24                        Sur      OM  22.5667   59.5289
#
#     Max Temp  Humidity  Cloudiness  Wind Speed Current Description
# 0      80.89        79         100        1.30     overcast clouds
# 1      85.82        62           0        8.05           clear sky
# 5      76.93        73           0       20.45          light rain
# 6      76.91        66         100       15.86     overcast clouds
# 7      62.44        69           2       11.59           clear sky
# 11     71.33        68           0       13.80           clear sky
# 14     77.58        61           0       12.91           clear sky
# 19     71.64        76         100       11.90     overcast clouds
# 23     84.02        79         100       10.49     overcast clouds
# 24     68.47        51           0        2.21           clear sky

# %%
# 4a. Determine if there are any empty rows.
preferred_cities_df.isnull().sum()
# Out:
# Unnamed: 0             0
# City                   0
# Country                5
# Lat                    0
# Lng                    0
# Max Temp               0
# Humidity               0
# Cloudiness             0
# Wind Speed             0
# Current Description    0
# dtype: int64

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have 
#empty rows.
clean_df = preferred_cities_df.dropna()
clean_df
# Out:
#      Unnamed: 0                       City Country      Lat       Lng  \
# 0             0  Santa Isabel Do Rio Negro      BR  -0.4139  -65.0192
# 1             1                   Acapulco      MX  16.8634  -99.8901
# 5             5                    Rikitea      PF -23.1203 -134.9692
# 6             6                   Celestun      MX  20.8667  -90.4000
# 7             7                  Esperance      AU -33.8667  121.9000
# ..          ...                        ...     ...      ...       ...
# 705         705                   Bulawayo      ZW -20.1500   28.5833
# 706         706                  Santa Ana      US  33.7456 -117.8678
# 707         707                     Ormara      PK  25.2088   64.6357
# 709         709               Batemans Bay      AU -35.7167  150.1833
# 713         713                  Kisangani      CD   0.5167   25.2000
#
#      Max Temp  Humidity  Cloudiness  Wind Speed Current Description
# 0       80.89        79         100        1.30     overcast clouds
# 1       85.82        62           0        8.05           clear sky
# 5       76.93        73           0       20.45          light rain
# 6       76.91        66         100       15.86     overcast clouds
# 7       62.44        69           2       11.59           clear sky
# ..        ...       ...         ...         ...                 ...
# 705     65.10        94         100       11.70          light rain
# 706     78.40        24          75        0.00       broken clouds
# 707     66.60        42           0        5.44           clear sky
# 709     68.09        92          97        5.03     overcast clouds
# 713     75.09        88         100        2.17     overcast clouds
#
# [373 rows x 10 columns]

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = clean_df[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()

# 5b. Create a new column "Hotel Name"
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#                          City Country  Max Temp Current Description      Lat  \
# 0   Santa Isabel Do Rio Negro      BR     80.89     overcast clouds  -0.4139
# 1                    Acapulco      MX     85.82           clear sky  16.8634
# 5                     Rikitea      PF     76.93          light rain -23.1203
# 6                    Celestun      MX     76.91     overcast clouds  20.8667
# 7                   Esperance      AU     62.44           clear sky -33.8667
# 11                   Coquimbo      CL     71.33           clear sky -29.9533
# 14                       Chuy      UY     77.58           clear sky -33.6971
# 19                East London      ZA     71.64     overcast clouds -33.0153
# 23                 Porto Novo      BJ     84.02     overcast clouds   6.4965
# 24                        Sur      OM     68.47           clear sky  22.5667
#
#          Lng Hotel Name
# 0   -65.0192
# 1   -99.8901
# 5  -134.9692
# 6   -90.4000
# 7   121.9000
# 11  -71.3436
# 14  -53.4616
# 19   27.9116
# 23    2.6036
# 24   59.5289

# %%
# 6a. Set parameters to search for hotels with 5000 meters.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# 6b. Iterate through the hotel DataFrame.
for index, row in hotel_df.iterrows():
    
    # 6c. Get latitude and longitude from DataFrame
    lat = row["Lat"]
    lng = row["Lng"]
    params["location"] = f"{lat},{lng}"
    
    # 6d. Set up the base URL for the Google Directions API to get JSON data.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # 6e. Make request and retrieve the JSON data from the search. 
    hotels = requests.get(base_url, params=params).json()
   
    
    # 6f. Get the first hotel from the results and store the name, if a hotel isn't found skip the city.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
        
    except (IndexError):
        print("Cannot find hotel...skipping.")  
        
hotel_df.head(10)
# Out:
# Cannot find hotel...skipping.
# Cannot find hotel...skipping.
# Cannot find hotel...skipping.
# Cannot find hotel...skipping.
# Cannot find hotel...skipping.
# Cannot find hotel...skipping.
# Cannot find hotel...skipping.
# Cannot find hotel...skipping.
# Cannot find hotel...skipping.
# Cannot find hotel...skipping.
# Cannot find hotel...skipping.
# Cannot find hotel...skipping.
# Cannot find hotel...skipping.
# Cannot find hotel...skipping.
# Cannot find hotel...skipping.
# Cannot find hotel...skipping.
# Cannot find hotel...skipping.
# Cannot find hotel...skipping.
# Cannot find hotel...skipping.
# Cannot find hotel...skipping.
# Cannot find hotel...skipping.
# Cannot find hotel...skipping.
# Cannot find hotel...skipping.
# Cannot find hotel...skipping.
# Cannot find hotel...skipping.
# Cannot find hotel...skipping.
# Cannot find hotel...skipping.
# Cannot find hotel...skipping.
# Cannot find hotel...skipping.
# Cannot find hotel...skipping.
# Cannot find hotel...skipping.
#                          City Country  Max Temp Current Description      Lat  \
# 0   Santa Isabel Do Rio Negro      BR     80.89     overcast clouds  -0.4139
# 1                    Acapulco      MX     85.82           clear sky  16.8634
# 5                     Rikitea      PF     76.93          light rain -23.1203
# 6                    Celestun      MX     76.91     overcast clouds  20.8667
# 7                   Esperance      AU     62.44           clear sky -33.8667
# 11                   Coquimbo      CL     71.33           clear sky -29.9533
# 14                       Chuy      UY     77.58           clear sky -33.6971
# 19                East London      ZA     71.64     overcast clouds -33.0153
# 23                 Porto Novo      BJ     84.02     overcast clouds   6.4965
# 24                        Sur      OM     68.47           clear sky  22.5667
#
#          Lng                 Hotel Name
# 0   -65.0192                  Hotel GSA
# 1   -99.8901  HS Hotsson Smart Acapulco
# 5  -134.9692            People ThankYou
# 6   -90.4000               Posada Lilia
# 7   121.9000      Hospitality Esperance
# 11  -71.3436          Hostel Del Puerto
# 14  -53.4616          Nuevo Hotel Plaza
# 19   27.9116                    Tu Casa
# 23    2.6036    Tour Eiffel Hotel Benin
# 24   59.5289            Sur Plaza Hotel

# %%
# 7. Drop the rows where there is no Hotel Name.
c = hotel_df.replace(r'^\s*$', np.nan, regex=True)
clean_hotel_df = c.dropna()
clean_hotel_df
# Out:
#                           City Country  Max Temp Current Description      Lat  \
# 0    Santa Isabel Do Rio Negro      BR     80.89     overcast clouds  -0.4139
# 1                     Acapulco      MX     85.82           clear sky  16.8634
# 5                      Rikitea      PF     76.93          light rain -23.1203
# 6                     Celestun      MX     76.91     overcast clouds  20.8667
# 7                    Esperance      AU     62.44           clear sky -33.8667
# ..                         ...     ...       ...                 ...      ...
# 705                   Bulawayo      ZW     65.10          light rain -20.1500
# 706                  Santa Ana      US     78.40       broken clouds  33.7456
# 707                     Ormara      PK     66.60           clear sky  25.2088
# 709               Batemans Bay      AU     68.09     overcast clouds -35.7167
# 713                  Kisangani      CD     75.09     overcast clouds   0.5167
#
#           Lng                               Hotel Name
# 0    -65.0192                                Hotel GSA
# 1    -99.8901                HS Hotsson Smart Acapulco
# 5   -134.9692                          People ThankYou
# 6    -90.4000                             Posada Lilia
# 7    121.9000                    Hospitality Esperance
# ..        ...                                      ...
# 705   28.5833                 4 On Housman Backpackers
# 706 -117.8678                     Santa Ana Travel Inn
# 707   64.6357  Crystal Beach and Camping Resort Ormara
# 709  150.1833               Batemans Bay Marina Resort
# 713   25.2000                       Grand Ramela Hotel
#
# [342 rows x 7 columns]

# %%
# 8a. Create the output File (CSV)
output_data_file = "weatherpy_vacation.csv"
# 8b. Export the City_Data into a csv
clean_hotel_df.to_csv(output_data_file, index_label="City_ID")

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Weather Description</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>

"""

# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = clean_hotel_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map. 
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
# 11b. Display the figure
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.4)
fig.add_layer(marker_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
